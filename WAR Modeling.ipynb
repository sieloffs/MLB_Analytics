# %%
import pandas as pd

# %%
df = pd.read_csv('data/WAR Predictor 15-25.csv')

# %%
df.head()
# Out:
#    Season               Name Team   PA       WAR       BB%        K%  \
# 0    2025         Oneil Cruz  PIT  544  1.580288  0.117647  0.319853
# 1    2017  Giancarlo Stanton  MIA  692  6.434607  0.122832  0.235549
# 2    2021  Giancarlo Stanton  NYY  579  3.050541  0.108808  0.271157
# 3    2018  Giancarlo Stanton  NYY  705  3.772407  0.099291  0.299291
# 4    2024         Oneil Cruz  PIT  599  3.603457  0.085142  0.302170
#
#     Barrel%  HardHit%         EV  ...       LD%       GB%       FB%     Pull%  \
# 0  0.178808  0.566225  95.835664  ...  0.145695  0.480132  0.374172  0.407285
# 1  0.173913  0.457666  92.009653  ...  0.160183  0.446224  0.393593  0.446224
# 2  0.157303  0.556180  95.100852  ...  0.185393  0.446629  0.367978  0.379213
# 3  0.151442  0.507212  93.694444  ...  0.185096  0.449519  0.365385  0.389423
# 4  0.156593  0.549451  95.480663  ...  0.184066  0.478022  0.337912  0.420330
#
#       Cent%     Oppo%       Spd          NameASCII  PlayerId  MLBAMID
# 0  0.384106  0.208609  7.068212         Oneil Cruz     21711   665833
# 1  0.352403  0.201373  2.259233  Giancarlo Stanton      4949   519317
# 2  0.339888  0.280899  0.603186  Giancarlo Stanton      4949   519317
# 3  0.370192  0.240385  3.768260  Giancarlo Stanton      4949   519317
# 4  0.329670  0.250000  6.152637         Oneil Cruz     21711   665833
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Season', 'Name', 'Team', 'PA', 'WAR', 'BB%', 'K%', 'Barrel%',
#        'HardHit%', 'EV', 'LA', 'maxEV', 'BABIP', 'LD%', 'GB%', 'FB%', 'Pull%',
#        'Cent%', 'Oppo%', 'Spd', 'NameASCII', 'PlayerId', 'MLBAMID'],
#       dtype='object')

# %%
y = df['WAR']
x = df.drop(['Season', 'PA', 'WAR', 'Name', 'Team', 'NameASCII', 'PlayerId', 'MLBAMID'], axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
